# %%
# -*- coding: utf-8 -*-
"""plot.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1CF_kIhKF4BAQJHL5RuEOaj9DGY1gzOeV
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
NESTED_LOOPS_DIR = "nested_loops/results/"

# %%
# I DIDNT UPDATE PATHS SO IT MAY NOT WORK
data_testGroup_300 = pd.read_csv(NESTED_LOOPS_DIR +'nestedLoopsMemory300_testGroup.csv',sep = ';')
data_testSize_300 = pd.read_csv(NESTED_LOOPS_DIR +"nestedLoopsMemory300_testSize.csv", sep = ';')
data_testGroup_100000 = pd.read_csv(NESTED_LOOPS_DIR +'nestedLoopsMemory100000_testGroup.csv',sep = ';')
data_testSize_100000 = pd.read_csv(NESTED_LOOPS_DIR +"nestedLoopsMemory100000_testSize.csv", sep = ';')

info_size = pd.read_csv(NESTED_LOOPS_DIR +'info_size.csv', sep= ';', header=None)
info_group = pd.read_csv(NESTED_LOOPS_DIR +'info_group.csv', sep= ';')


# We don't care for the first file
data_testGroup_300 = data_testGroup_300[1:]
data_testGroup_100000 = data_testGroup_100000[1:]

file_size = info_size[1].values

# We fixed size 400 000, and we change proportion for group size 
group_size = info_group[' groupsize / filesize'].values

fig = plt.figure(1, figsize=(15, 10))

plt.plot(file_size, data_testSize_300[' Single'].values, '-', marker='o', label='Single thread')
plt.plot(file_size, data_testSize_300[' Multi'].values, '-',marker='o', label="Multi thread")
plt.plot(file_size, data_testSize_300[' Spark'], '-', marker='o', label="Spark")
plt.legend()
plt.title("Nested Loops Memory_300 depending in size of data")
plt.xlabel('Size of file')
plt.ylabel('time to run in ms')

plt.show()

fig = plt.figure(1, figsize=(15, 10))

plt.plot(file_size, data_testSize_100000[' Single'].values, '-', marker='o', label='Single thread')
plt.plot(file_size, data_testSize_100000[' Multi'].values, '-',marker='o', label="Multi thread")
plt.plot(file_size, data_testSize_100000[' Spark'], '-', marker='o', label="Spark")
plt.legend()
plt.title("Nested Loops Memory_300 depending in size of data")
plt.xlabel('Proportion of group in file size = 400 000')
plt.ylabel('time to run in ms')

plt.show()

fig = plt.figure(1, figsize=(15, 10))

plt.plot(group_size, data_testGroup_300[' Single'].values, '-', marker='o', label='Single thread')
plt.plot(group_size, data_testGroup_300[' Multi'].values, '-',marker='o', label="Multi thread")
plt.plot(group_size, data_testGroup_300[' Spark'], '-', marker='o', label="Spark")
plt.legend()
plt.title("Nested Loops Memory_300 depending in fraction of group in data size of 400 000 rows")
plt.xlabel('Proportion of group in file size = 400 000')
plt.ylabel('time to run in ms')

plt.show()

fig = plt.figure(1, figsize=(15, 10))

plt.plot(group_size, data_testGroup_100000[' Single'].values, '-', marker='o', label='Single thread')
plt.plot(group_size, data_testGroup_100000[' Multi'].values, '-',marker='o', label="Multi thread")
plt.plot(group_size, data_testGroup_100000[' Spark'], '-', marker='o', label="Spark")
plt.legend()
plt.title("Nested Loops Memory_100000 depending in fraction of group in data size of 400 000 rows")
plt.xlabel('Proportion of group in file size = 400 000')
plt.ylabel('time to run in ms')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-122-715fc802ccd4> in <module>()
#       1 # I DIDNT UPDATE PATHS SO IT MAY NOT WORK
# ----> 2 data_testGroup_300 = pd.read_csv(NESTED_LOOPS_DIR +'nestedLoopsMemory300_testGroup.csv',sep = ';')
#       3 data_testSize_300 = pd.read_csv(NESTED_LOOPS_DIR +"nestedLoopsMemory300_testSize.csv", sep = ';')
#       4 data_testGroup_100000 = pd.read_csv(NESTED_LOOPS_DIR +'nestedLoopsMemory100000_testGroup.csv',sep = ';')
#       5 data_testSize_100000 = pd.read_csv(NESTED_LOOPS_DIR +"nestedLoopsMemory100000_testSize.csv", sep = ';')
#
# C:\Users\BOIGE\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\Users\BOIGE\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# C:\Users\BOIGE\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# C:\Users\BOIGE\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# C:\Users\BOIGE\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nested_loops/results/nestedLoopsMemory300_testGroup.csv'

# %%
data_testGroup = pd.read_csv('Hash/final/result_group.csv',sep = ';')
data_testSize = pd.read_csv('Hash/final/result_size.csv',sep = ';')

# %%
## SORT FILES
index = data_testGroup.apply(lambda x:int(x[0][:-4]),axis=1).sort_values().index
data_testGroup = data_testGroup.loc[index].reset_index(drop=True)
index = data_testSize.apply(lambda x:int(x[0][:-4]),axis=1).sort_values().index
data_testSize = data_testSize.loc[index].reset_index(drop=True)

# %%
# We don't care for the first file
data_testGroup = data_testGroup[1:]
info_size = pd.read_csv('dataGen/info_size.csv', sep= ';', header=None)
info_group = pd.read_csv('dataGen/info_group.csv', sep= ';',skiprows=1)

# %%
len(file_size)
# Out:
# 39

# %%
file_size = info_size[1].values[:-2]

# We fixed size 400 000, and we change proportion for group size 
group_size = info_group['groupsize'].values

fig = plt.figure(1, figsize=(15, 10))

plt.plot(file_size, data_testSize[' Single'].values, '-', marker='o', label='Single thread')
plt.plot(file_size, data_testSize[' Multi'].values, '-',marker='o', label="Multi thread")
plt.plot(file_size, data_testSize[' Spark'], '-', marker='o', label="Spark")
plt.legend()
plt.title("Nested Loops Memory depending in size of data")
plt.xlabel('Size of file')
plt.ylabel('time to run in ms')

plt.show()



fig = plt.figure(1, figsize=(15, 10))

plt.plot(group_size, data_testGroup[' Single'].values, '-', marker='o', label='Single thread')
plt.plot(group_size, data_testGroup[' Multi'].values, '-',marker='o', label="Multi thread")
plt.plot(group_size, data_testGroup[' Spark'], '-', marker='o', label="Spark")
plt.legend()
plt.title("Nested Loops Memory depending in fraction of group in data size of 400 000 rows")
plt.xlabel('Proportion of group in file size = 400 000')
plt.ylabel('time to run in ms')

plt.show()
